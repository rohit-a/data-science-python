# %% [markdown]
# # Introduction

# %% [markdown]
# ## Why Python
#
# - **Simplicity**: Beginner Friendly, Readability, Simple Syntax
# - **Libraries**: Libraries available for almost any use case. NumPy, Pandas, sklearn etc
# - **Multi-paradigm approach**: Functional, Procedural, Object-oriented programming and Aspect-oriented programming styles.
# - **Easy Integrations**: Highly embeddable in applications, Direct calling to and from C, C++, JAVA
# - **Jupyter Notebooks**: Expressive code with mark downs, visualizations in browser based interface. Google Colab.
# - **Community**: Acitve contributors to serveral packages

# %% [markdown]
# ## Comparison with other languages
#
# Python is considered to be one of the slower languages in terms of performance since it is interpreted and dynamically typed (more work at run time).
#
# But programs are also smaller and easy to develop.
#
# In practice, the choice of a programming language is often dictated by other real-world constraints such as cost, availability, training, and prior investment, or even emotional attachment.(https://www.python.org/doc/essays/comparisons/)
#
#
# #### Sample benchmarks
# (https://julialang.org/benchmarks/)
#
# ![Execution%20Times.JPG](attachment:Execution%20Times.JPG)

# %% [markdown]
# ## Introduction to Numpy, Matplotlib, Pandas and Seaborn
#
# - **numpy** is an open source Python library used for scientific computing and provides a host of features that allow a Python programmer to work with high-performance arrays and matrices. ndarrays are stored more efficiently than Python lists and allow mathematical operations to be vectorized, which results in significantly higher performance than with looping constructs in Python. (https://numpy.org/)
#
# - **pandas** is a package for data manipulation that uses the DataFrame objects. It provides a fast, flexible, and expressive data structures designed to make working with “relational” or “labeled” data both easy and intuitive. It relies heavily on numpy arrays for the implementation of pandas data objects and shares many of its features. In addition, pandas builds upon functionality provided by NumPy. (https://pandas.pydata.org/docs/index.html)
#
# - **matplotlib** is the basis for static plotting in Python. Many other visualization tools are built on top of it, such as seaborn and Pandas DataFrames plot method. It is versatile meaning it is able to plot anything, but non-basic plots can be very verbose and complex to implement. (https://matplotlib.org/gallery/index.html)
#
# - **seaborn** is built on top of matplotlib and integrates very well with pandas. The plots are naturally prettier and easy to customize with color palettes. Making complex plots with low effort is accomplished by some features like automatic labels for the axes and grouping with specialized support for categorical variables. Even complex tasks like multi-plotting are abstracted to a high-level grid structure. There are many built-in complex plots like cluster maps, pair plots etc which are very convenient for analyzing data quickly and effectively. (https://seaborn.pydata.org/examples/index.html)

# %% [markdown]
# ## About Covid19 Data
#
# - Sourced from https://coronavirus.jhu.edu/data
# - Data Repositroy available at https://github.com/CSSEGISandData/COVID-19
# - Daily reports and time series data available for US (States and Zips) and Worldwide countries.
# - We will be focussing on worldwide time series data (3 Files each for confirmed, recovered and deaths by country and date).
